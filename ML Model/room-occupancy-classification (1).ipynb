# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from warnings import filterwarnings
filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/room-occupancy/file.csv

# %% [markdown]
# ## 1. Reading Dataset

# %%
data = pd.read_csv('/kaggle/input/room-occupancy/file.csv')
print(data.shape)
data.head()
# Out:
# (2665, 6)
#    Temperature  Humidity       Light         CO2  HumidityRatio  Occupancy
# 0      23.7000    26.272  585.200000  749.200000       0.004764          1
# 1      23.7180    26.290  578.400000  760.400000       0.004773          1
# 2      23.7300    26.230  572.666667  769.666667       0.004765          1
# 3      23.7225    26.125  493.750000  774.750000       0.004744          1
# 4      23.7540    26.200  488.600000  779.000000       0.004767          1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    2665 non-null   float64
#  1   Humidity       2665 non-null   float64
#  2   Light          2665 non-null   float64
#  3   CO2            2665 non-null   float64
#  4   HumidityRatio  2665 non-null   float64
#  5   Occupancy      2665 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 125.0 KB

# %%
data.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378
#
#          Occupancy
# count  2665.000000
# mean      0.364728
# std       0.481444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df = data.copy()

# %%
df['Occupancy'] = df.Occupancy.replace({0:'Emptied',1:'Occupied'}).astype('object')

df_emptied = df[df['Occupancy'] == 'Emptied']
df_occupied = df[df['Occupancy'] == 'Occupied']

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %%
colors=('#453CC9','#22AFF1')
explode=[0,0.1]
df["Occupancy"].value_counts().plot(kind='pie',shadow=True,explode=explode,colors=colors,autopct='%.2f',figsize=(8,6))
plt.title('Ratio of occupancy')
plt.show()

# %%
plt.subplots(figsize=(8,4))
plt.title('Correlation between variables')
sns.heatmap(data.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:title={'center':'Correlation between variables'}>

# %% [markdown]
# * Temperatures

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Temperature All Rooms')
ax = plt.hist(df['Temperature'], bins=50, density = False)
plt.xlabel('Temperatures All Customers')
# Out:
# Text(0.5, 0, 'Temperatures All Customers')

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Temperature Rooms')
plt.hist(df_emptied['Temperature'], bins=50, density = False)
plt.hist(df_occupied['Temperature'], bins=50, density = False)
plt.xlabel('Temperatures Rooms')
# Out:
# Text(0.5, 0, 'Temperatures Rooms')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df_emptied['Temperature'],label='Empety')
sns.distplot(df_occupied['Temperature'],label='Occupied')
plt.legend()

# %% [markdown]
# * Humidity

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Humidity All Rooms')
ax = plt.hist(df['Humidity'], bins=50, density = False)
plt.xlabel('Humidity All Customers')
# Out:
# Text(0.5, 0, 'Humidity All Customers')

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Humidity Rooms')
plt.hist(df_emptied['Humidity'], bins=50, density = False)
plt.hist(df_occupied['Humidity'], bins=50, density = False)
plt.xlabel('Humidity Rooms')
# Out:
# Text(0.5, 0, 'Humidity Rooms')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df_emptied['Humidity'],label='Empety')
sns.distplot(df_occupied['Humidity'],label='Occupied')
plt.legend()

# %% [markdown]
# * Light

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Light All Rooms')
ax = plt.hist(df['Light'], bins=50, density = False)
plt.xlabel('Light All Customers')
# Out:
# Text(0.5, 0, 'Light All Customers')

# %%
plt.figure(figsize = (8,6))
plt.title('Number of Light Rooms')
plt.hist(df_emptied['Light'], bins=50, density = False)
plt.hist(df_occupied['Light'], bins=50, density = False)
plt.xlabel('Light Rooms')
# Out:
# Text(0.5, 0, 'Light Rooms')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df_emptied['Light'],label='Empety')
sns.distplot(df_occupied['Light'],label='Occupied')
plt.legend()

# %% [markdown]
# * CO2

# %%
plt.figure(figsize = (8,6))
plt.title('Number of CO2 All Rooms')
ax = plt.hist(df['CO2'], bins=50, density = False)
plt.xlabel('CO2 All Customers')
# Out:
# Text(0.5, 0, 'CO2 All Customers')

# %%
plt.figure(figsize = (8,6))
plt.title('Number of CO2 Rooms')
plt.hist(df_emptied['CO2'], bins=50, density = False)
plt.hist(df_occupied['CO2'], bins=50, density = False)
plt.xlabel('CO2 Rooms')
# Out:
# Text(0.5, 0, 'CO2 Rooms')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df_emptied['CO2'],label='Empety')
sns.distplot(df_occupied['CO2'],label='Occupied')
plt.legend()

# %% [markdown]
# * HumidityRatio

# %%
plt.figure(figsize = (8,6))
plt.title('Number of HumidityRatio All Rooms')
ax = plt.hist(df['HumidityRatio'], bins=50, density = False)
plt.xlabel('HumidityRatio All Customers')
# Out:
# Text(0.5, 0, 'HumidityRatio All Customers')

# %%
plt.figure(figsize = (8,6))
plt.title('Number of HumidityRatio Rooms')
plt.hist(df_emptied['HumidityRatio'], bins=50, density = False)
plt.hist(df_occupied['HumidityRatio'], bins=50, density = False)
plt.xlabel('HumidityRatio Rooms')
# Out:
# Text(0.5, 0, 'HumidityRatio Rooms')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df_emptied['HumidityRatio'],label='Empety')
sns.distplot(df_occupied['HumidityRatio'],label='Occupied')
plt.legend()

# %% [markdown]
# ## 3. Data Preprocessing

# %%
def clean_outliers(df,features):
    for i in features:
        Q1 = df[i].quantile(0.25)
        Q3 = df[i].quantile(0.75)
        IQR = (Q3-Q1)
        print("Feature {} has min value: {} max value: {}".format(i,Q1-IQR*1.5,Q3+IQR*1.5))
        df = df[((df[i]>(Q1-IQR*1.5))&(df[i]<(Q3+IQR*1.5)))]
    return df

# %%
numlist = data.columns
print(numlist)
# Out:
# Index(['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio',
#        'Occupancy'],
#       dtype='object')

# %%
data_clean = clean_outliers(data,numlist)
print("New shape: ",data_clean.shape)
# Out:
# Feature Temperature has min value: 18.08999999999995 max value: 24.916666666666746
# Feature Humidity has min value: 17.86499999999996 max value: 32.25166666666674
# Feature Light has min value: -663.75 max value: 1106.25
# Feature CO2 has min value: -269.46874999999966 max value: 1691.7812499999995
# Feature HumidityRatio has min value: 0.0020214003864498006 max value: 0.006038621453288399
# Feature Occupancy has min value: -1.5 max value: 2.5
# New shape:  (2662, 6)

# %% [markdown]
# ## 4. Building Model

# %% [markdown]
# #### Split train test data

# %%
features = data_clean.drop(columns='Occupancy')
target = data_clean['Occupancy']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2129, 5)
# (533, 5)
# (2129,)
# (533,)

# %% [markdown]
# #### Model Training

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score
from sklearn.metrics import f1_score,confusion_matrix,roc_auc_score

def evaluation(y_test,y_pred):
  acc = accuracy_score(y_test,y_pred)
  rcl = recall_score(y_test,y_pred)
  f1 = f1_score(y_test,y_pred)
  auc_score = roc_auc_score(y_test,y_pred)
  prec_score = precision_score(y_test,y_pred)
 

  metric_dict={'accuracy': round(acc,3),
               'recall': round(rcl,3),
               'F1 score': round(f1,3),
               'auc score': round(auc_score,3),
               'precision': round(prec_score,3) 
              }

  return print(metric_dict)

# %%
Results = pd.DataFrame({'Model': [],'Accuracy Score': [], 'Recall':[], 'F1score':[]})

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=4)
tree.fit(X_train,y_train)
y_pred1 = tree.predict(X_test)
res = pd.DataFrame({"Model":['DecisionTreeClassifier'],
                    "Accuracy Score": [accuracy_score(y_pred1,y_test)],
                    "Recall": [recall_score(y_test,y_pred1)],
                    "F1score": [f1_score(y_test,y_pred1)]})
Results = Results.append(res)

# %%
pd.crosstab(y_test,y_pred1,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          330    7
# 1            0  196

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=2500,max_depth=4)
rfc.fit(X_train,y_train)
y_pred2 = rfc.predict(X_test)
res = pd.DataFrame({"Model":['RandomForestClassifier'],
                    "Accuracy Score": [accuracy_score(y_pred2,y_test)],
                    "Recall": [recall_score(y_test,y_pred2)],
                    "F1score": [f1_score(y_test,y_pred2)]})
Results = Results.append(res)

# %%
pd.crosstab(y_test,y_pred2,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          329    8
# 1            0  196

# %% [markdown]
# #### KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred3 = knn.predict(X_test)
res = pd.DataFrame({"Model":['KNeighborsClassifier'],
                    "Accuracy Score": [accuracy_score(y_pred3,y_test)],
                    "Recall": [recall_score(y_test,y_pred3)],
                    "F1score": [f1_score(y_test,y_pred3)]})
Results = Results.append(res)

# %%
pd.crosstab(y_test,y_pred3,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          333    4
# 1            4  192

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
y_pred4 = svc.predict(X_test)
res = pd.DataFrame({"Model":['SVC'],
                    "Accuracy Score": [accuracy_score(y_pred4,y_test)],
                    "Recall": [recall_score(y_test,y_pred4)],
                    "F1score": [f1_score(y_test,y_pred4)]})
Results = Results.append(res)

# %%
pd.crosstab(y_test,y_pred4,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          328    9
# 1            0  196

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred5 = lr.predict(X_test)
res = pd.DataFrame({"Model":['LogisticRegression'],
                    "Accuracy Score": [accuracy_score(y_pred5,y_test)],
                    "Recall": [recall_score(y_test,y_pred5)],
                    "F1score": [f1_score(y_test,y_pred5)]})
Results = Results.append(res)

# %%
pd.crosstab(y_test,y_pred5,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          328    9
# 1            0  196

# %% [markdown]
# #### Results

# %%
Results.sort_values(by='Accuracy Score',ascending=True)
# Out:
#                     Model  Accuracy Score    Recall   F1score
# 0                     SVC        0.983114  1.000000  0.977556
# 0      LogisticRegression        0.983114  1.000000  0.977556
# 0  RandomForestClassifier        0.984991  1.000000  0.980000
# 0    KNeighborsClassifier        0.984991  0.979592  0.979592
# 0  DecisionTreeClassifier        0.986867  1.000000  0.982456

# %% [markdown]
# How we see - **DecisionTreeClassifier** gives the best results

# %% [markdown]
# ## 5. Model Evalution

# %%
from sklearn.metrics import classification_report,plot_confusion_matrix,plot_roc_curve

# %% [markdown]
# #### Decision Tree Classifier

# %%
model = DecisionTreeClassifier(max_depth=4)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
print(" Best evaluation parameters achieved with DecisionTree:") 
evaluation(y_test,y_pred)
# Out:
#  Best evaluation parameters achieved with DecisionTree:
# {'accuracy': 0.987, 'recall': 1.0, 'F1 score': 0.982, 'auc score': 0.99, 'precision': 0.966}

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       337
#            1       0.97      1.00      0.98       196
#
#     accuracy                           0.99       533
#    macro avg       0.98      0.99      0.99       533
# weighted avg       0.99      0.99      0.99       533

# %%
plot_confusion_matrix(model,X_test,y_test,cmap='YlOrBr')

# %%
plot_roc_curve(model,X_test,y_test)

# %%
from sklearn.model_selection import cross_val_score

cv_accuracy = cross_val_score(model,X_train,y_train,cv=5,scoring='accuracy')
print(f'Cross Validaion accuracy Scores: {cv_accuracy}')
print(f'Cross Validation accuracy Mean Score: {cv_accuracy.mean()}')
# Out:
# Cross Validaion accuracy Scores: [0.97652582 0.98356808 0.99295775 0.9741784  0.97647059]
# Cross Validation accuracy Mean Score: 0.9807401270367301

# %% [markdown]
# #### Feature Importance

# %%
feat_importance = model.feature_importances_
feat_importance = pd.DataFrame(feat_importance,columns=['Score'],index=features.columns)

# %%
feat_importance.sort_values(by='Score').style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
# #T_68cce_row0_col0{
#             background-color:  #fff7ec;
#             color:  #000000;
#         }#T_68cce_row1_col0{
#             background-color:  #fff7eb;
#             color:  #000000;
#         }#T_68cce_row2_col0{
#             background-color:  #fff6ea;
#             color:  #000000;
#         }#T_68cce_row3_col0{
#             background-color:  #fff5e7;
#             color:  #000000;
#         }#T_68cce_row4_col0{
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }</style><table id="T_68cce_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68cce_level0_row0" class="row_heading level0 row0" >HumidityRatio</th>
#                         <td id="T_68cce_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_68cce_level0_row1" class="row_heading level0 row1" >CO2</th>
#                         <td id="T_68cce_row1_col0" class="data row1 col0" >0.003829</td>
#             </tr>
#             <tr>
#                         <th id="T_68cce_level0_row2" class="row_heading level0 row2" >Temperature</th>
#                         <td id="T_68cce_row2_col0" class="data row2 col0" >0.007664</td>
#             </tr>
#             <tr>
#                         <th id="T_68cce_level0_row3" class="row_heading level0 row3" >Humidity</th>
#                         <td id="T_68cce_row3_col0" class="data row3 col0" >0.018417</td>
#             </tr>
#             <tr>
#                         <th id="T_68cce_level0_row4" class="row_heading level0 row4" >Light</th>
#                         <td id="T_68cce_row4_col0" class="data row4 col0" >0.970091</td>
#             </tr>
#     </tbody></table>

# %%
plt.figure(figsize=(8,4))
plt.title('Feature Importances')
sns.barplot(x=feat_importance.Score,y=feat_importance.index)
# Out:
# <AxesSubplot:title={'center':'Feature Importances'}, xlabel='Score'>

# %% [markdown]
# #### Visualize a Decision Tree

# %%
from sklearn import tree

feature_names = features.columns
class_names = ['Emptied','Occupied']

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, 
                   feature_names = feature_names,  
                   class_names = class_names,
                   filled=True)

# %%
fig.savefig('decistion_tree.png')

# %% [markdown]
# **Conclusion:**
#
# The chosen model was **DecisionTree Classification** since it´s the most accurate, and got a perfecf accuracy.
#
# Through the analysis of feature importance, we can assume that **Light** is the most important features of classification.
